# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !unzip -q /content/drive/MyDrive/new_dataset.zip -d /content/

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.0/613.0 kB 10.0 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train epochs=100 data=/content/data_custom.yaml model=yolov8m.pt imgsz=640 batch=15
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 210MB/s]
# Ultralytics YOLOv8.0.126 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt show=True conf=0.3 source=2.jpg
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.126 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68127420 parameters, 0 gradients
#
# image 1/1 /content/2.jpg: 640x640 (no detections), 94.5ms
# Speed: 3.4ms preprocess, 94.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
